# %%
import pandas as pd
from functools import reduce

# %%
pd.set_option('display.max_rows', None)

# %%
dates = pd.read_csv('csv_from_scrape/baseball_dates_index.csv')

# %%
mccann_2005 = pd.read_csv('csv_from_scrape/mccann_2005_df.csv')
mccann_2005.columns.values[1] = 'DATE'
mccann_2005.columns.values[2] = '2005 Batting Averages'
mccann_2005.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2005 Batting Averages
# 0   06-10                  0.667
# 1   06-11                  0.429
# 2   06-13                  0.333
# 3   06-15                  0.286
# 4   06-19                  0.267
# 5   06-21                  0.263
# 6   06-26                  0.348
# 7   06-29                  0.348
# 8   06-30                  0.385
# 9   07-01                  0.333
# 10  07-07                  0.313
# 11  07-09                  0.313
# 12  07-15                  0.333
# 13  07-16                  0.333
# 14  07-20                  0.310
# 15  07-23                  0.310
# 16  07-24                  0.289
# 17  07-26                  0.292
# 18  07-27                  0.275
# 19  07-28                  0.273
# 20  07-31                  0.281
# 21  08-02                  0.306
# 22  08-04                  0.318
# 23  08-05                  0.313
# 24  08-06                  0.296
# 25  08-07                  0.297
# 26  08-09                  0.308
# ...

# %%
mccann_2006 = pd.read_csv('csv_from_scrape/mccann_2006_df.csv')
mccann_2006.columns.values[1] = 'DATE'
mccann_2006.columns.values[2] = '2006 Batting Averages'
mccann_2006.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2006 Batting Averages
# 0    04-03                  0.250
# 1    04-04                  0.250
# 2    04-05                  0.222
# 3    04-06                  0.231
# 4    04-07                  0.313
# 5    04-09                  0.250
# 6    04-10                  0.250
# 7    04-12                  0.286
# 8    04-13                  0.267
# 9    04-14                  0.265
# 10   04-15                  0.243
# 11   04-16                  0.263
# 12   04-17                  0.244
# 13   04-18                  0.244
# 14   04-21                  0.292
# 15   04-23                  0.288
# 16   04-24                  0.283
# 17   04-25                  0.268
# 18   04-26                  0.305
# 19   04-28                  0.290
# 20   04-30                  0.308
# 21   05-01                  0.324
# 22   05-02                  0.324
# 23   05-03                  0.324
# 24   05-04                  0.316
# 25   05-05                  0.317
# ...

# %%
mccann_2007 = pd.read_csv('csv_from_scrape/mccann_2007_df.csv')
mccann_2007.columns.values[1] = 'DATE'
mccann_2007.columns.values[2] = '2007 Batting Averages'
mccann_2007.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2007 Batting Averages
# 0    04-02                  0.750
# 1    04-04                  0.556
# 2    04-05                  0.500
# 3    04-06                  0.467
# 4    04-07                  0.368
# 5    04-08                  0.364
# 6    04-10                  0.360
# 7    04-11                  0.345
# 8    04-12                  0.303
# 9    04-15                  0.324
# 10   04-16                  0.300
# 11   04-17                  0.318
# 12   04-18                  0.327
# 13   04-20                  0.333
# 14   04-21                  0.345
# 15   04-22                  0.339
# 16   04-23                  0.333
# 17   04-24                  0.338
# 18   04-25                  0.319
# 19   04-27                  0.311
# 20   04-28                  0.295
# 21   04-29                  0.291
# 22   04-30                  0.289
# 23   05-01                  0.298
# 24   05-04                  0.314
# 25   05-05                  0.311
# ...

# %%
mccann_2008 = pd.read_csv('csv_from_scrape/mccann_2008_df.csv')
mccann_2008.columns.values[1] = 'DATE'
mccann_2008.columns.values[2] = '2008 Batting Averages'
mccann_2008.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2008 Batting Averages
# 0    03-30                  0.250
# 1    03-31                  0.300
# 2    04-02                  0.308
# 3    04-03                  0.286
# 4    04-05                  0.294
# 5    04-06                  0.300
# 6    04-07                  0.261
# 7    04-08                  0.269
# 8    04-09                  0.333
# 9    04-11                  0.303
# 10   04-12                  0.351
# 11   04-13                  0.317
# 12   04-15                  0.289
# 13   04-16                  0.271
# 14   04-17                  0.283
# 15   04-18                  0.298
# 16   04-19                  0.283
# 17   04-20                  0.279
# 18   04-21                  0.292
# 19   04-22                  0.275
# 20   04-23                  0.284
# 21   04-24                  0.286
# 22   04-25                  0.296
# 23   04-26                  0.294
# 24   04-27                  0.292
# 25   04-29                  0.290
# ...

# %%
mccann_2009 = pd.read_csv('csv_from_scrape/mccann_2009_df.csv')
mccann_2009.columns.values[1] = 'DATE'
mccann_2009.columns.values[2] = '2009 Batting Averages'
mccann_2009.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2009 Batting Averages
# 0    04-05                  0.250
# 1    04-07                  0.143
# 2    04-08                  0.273
# 3    04-10                  0.400
# 4    04-11                  0.316
# 5    04-12                  0.318
# 6    04-14                  0.269
# 7    04-15                  0.241
# 8    04-16                  0.233
# 9    04-17                  0.219
# 10   04-18                  0.200
# 11   04-21                  0.189
# 12   04-22                  0.195
# 13   05-08                  0.205
# 14   05-09                  0.250
# 15   05-10                  0.250
# 16   05-11                  0.246
# 17   05-12                  0.279
# 18   05-13                  0.274
# 19   05-15                  0.273
# 20   05-16                  0.275
# 21   05-18                  0.282
# 22   05-19                  0.280
# 23   05-21                  0.266
# 24   05-22                  0.284
# 25   05-23                  0.282
# ...

# %%
mccann_2010 = pd.read_csv('csv_from_scrape/mccann_2010_df.csv')
mccann_2010.columns.values[1] = 'DATE'
mccann_2010.columns.values[2] = '2010 Batting Averages'
mccann_2010.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2010 Batting Averages
# 0    04-05                  0.667
# 1    04-07                  0.400
# 2    04-08                  0.250
# 3    04-09                  0.300
# 4    04-10                  0.231
# 5    04-11                  0.294
# 6    04-12                  0.300
# 7    04-14                  0.348
# 8    04-15                  0.346
# 9    04-17                  0.300
# 10   04-18                  0.281
# 11   04-20                  0.286
# 12   04-21                  0.282
# 13   04-22                  0.279
# 14   04-23                  0.261
# 15   04-24                  0.255
# 16   04-25                  0.271
# 17   04-26                  0.255
# 18   04-27                  0.250
# 19   04-29                  0.250
# 20   04-30                  0.234
# 21   05-02                  0.242
# 22   05-04                  0.257
# 23   05-05                  0.243
# 24   05-08                  0.250
# 25   05-09                  0.241
# ...

# %%
mccann_2011 = pd.read_csv('csv_from_scrape/mccann_2011_df.csv')
mccann_2011.columns.values[1] = 'DATE'
mccann_2011.columns.values[2] = '2011 Batting Averages'
mccann_2011.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2011 Batting Averages
# 0    03-31                  0.500
# 1    04-02                  0.375
# 2    04-03                  0.462
# 3    04-04                  0.400
# 4    04-05                  0.333
# 5    04-06                  0.409
# 6    04-07                  0.423
# 7    04-08                  0.433
# 8    04-09                  0.406
# 9    04-10                  0.361
# 10   04-12                  0.350
# 11   04-13                  0.326
# 12   04-14                  0.340
# 13   04-16                  0.327
# 14   04-17                  0.327
# 15   04-18                  0.339
# 16   04-19                  0.356
# 17   04-20                  0.349
# 18   04-21                  0.338
# 19   04-22                  0.319
# 20   04-23                  0.311
# 21   04-24                  0.316
# 22   04-25                  0.296
# 23   04-27                  0.310
# 24   04-29                  0.303
# 25   04-30                  0.301
# ...

# %%
mccann_2012 = pd.read_csv('csv_from_scrape/mccann_2012_df.csv')
mccann_2012.columns.values[1] = 'DATE'
mccann_2012.columns.values[2] = '2012 Batting Averages'
mccann_2012.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2012 Batting Averages
# 0    04-05                  0.000
# 1    04-07                  0.000
# 2    04-08                  0.091
# 3    04-09                  0.133
# 4    04-10                  0.158
# 5    04-13                  0.292
# 6    04-14                  0.269
# 7    04-15                  0.276
# 8    04-16                  0.273
# 9    04-17                  0.278
# 10   04-19                  0.293
# 11   04-20                  0.304
# 12   04-21                  0.286
# 13   04-22                  0.264
# 14   04-24                  0.263
# 15   04-25                  0.262
# 16   04-27                  0.250
# 17   04-29                  0.242
# 18   04-30                  0.229
# 19   05-01                  0.233
# 20   05-02                  0.241
# 21   05-04                  0.235
# 22   05-05                  0.247
# 23   05-07                  0.237
# 24   05-08                  0.232
# 25   05-09                  0.229
# ...

# %%
mccann_2013 = pd.read_csv('csv_from_scrape/mccann_2013_df.csv')
mccann_2013.columns.values[1] = 'DATE'
mccann_2013.columns.values[2] = '2013 Batting Averages'
mccann_2013.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2013 Batting Averages
# 0    05-06                  0.000
# 1    05-07                  0.125
# 2    05-09                  0.308
# 3    05-10                  0.313
# 4    05-12                  0.278
# 5    05-13                  0.333
# 6    05-14                  0.318
# 7    05-15                  0.296
# 8    05-17                  0.267
# 9    05-18                  0.242
# 10   05-19                  0.229
# 11   05-21                  0.282
# 12   05-24                  0.318
# 13   05-25                  0.292
# 14   05-27                  0.269
# 15   05-28                  0.281
# 16   05-29                  0.267
# 17   05-30                  0.281
# 18   05-31                  0.269
# 19   06-01                  0.265
# 20   06-02                  0.264
# 21   06-03                  0.280
# 22   06-04                  0.269
# 23   06-06                  0.268
# 24   06-07                  0.265
# 25   06-08                  0.253
# ...

# %%
mccann_2014 = pd.read_csv('csv_from_scrape/mccann_2014_df.csv')
mccann_2014.columns.values[1] = 'DATE'
mccann_2014.columns.values[2] = '2014 Batting Averages'
mccann_2014.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2014 Batting Averages
# 0    04-01                  0.250
# 1    04-02                  0.375
# 2    04-04                  0.308
# 3    04-05                  0.235
# 4    04-06                  0.238
# 5    04-07                  0.200
# 6    04-08                  0.172
# 7    04-09                  0.152
# 8    04-10                  0.167
# 9    04-11                  0.162
# 10   04-12                  0.195
# 11   04-13                  0.205
# 12   04-16                  0.208
# 13   04-17                  0.226
# 14   04-18                  0.228
# 15   04-19                  0.220
# 16   04-20                  0.230
# 17   04-22                  0.262
# 18   04-23                  0.261
# 19   04-24                  0.257
# 20   04-25                  0.244
# 21   04-27                  0.235
# 22   04-29                  0.224
# 23   05-01                  0.225
# 24   05-02                  0.229
# 25   05-03                  0.228
# ...

# %%
mccann_2015 = pd.read_csv('csv_from_scrape/mccann_2015_df.csv')
mccann_2015.columns.values[1] = 'DATE'
mccann_2015.columns.values[2] = '2015 Batting Averages'
mccann_2015.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2015 Batting Averages
# 0    04-06                  0.250
# 1    04-08                  0.143
# 2    04-10                  0.231
# 3    04-12                  0.278
# 4    04-14                  0.227
# 5    04-15                  0.200
# 6    04-17                  0.179
# 7    04-18                  0.250
# 8    04-20                  0.257
# 9    04-21                  0.225
# 10   04-22                  0.244
# 11   04-23                  0.224
# 12   04-24                  0.245
# 13   04-25                  0.232
# 14   04-27                  0.250
# 15   04-28                  0.266
# 16   04-29                  0.266
# 17   05-01                  0.265
# 18   05-02                  0.250
# 19   05-03                  0.247
# 20   05-05                  0.250
# 21   05-06                  0.238
# 22   05-07                  0.227
# 23   05-08                  0.231
# 24   05-09                  0.239
# 25   05-10                  0.242
# ...

# %%
mccann_2016 = pd.read_csv('csv_from_scrape/mccann_2016_df.csv')
mccann_2016.columns.values[1] = 'DATE'
mccann_2016.columns.values[2] = '2016 Batting Averages'
mccann_2016.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2016 Batting Averages
# 0    04-05                  0.333
# 1    04-06                  0.429
# 2    04-07                  0.455
# 3    04-09                  0.467
# 4    04-12                  0.500
# 5    04-14                  0.455
# 6    04-15                  0.385
# 7    04-16                  0.370
# 8    04-17                  0.333
# 9    04-19                  0.286
# 10   04-20                  0.289
# 11   04-21                  0.275
# 12   04-22                  0.302
# 13   04-23                  0.304
# 14   04-24                  0.280
# 15   04-26                  0.259
# 16   04-27                  0.259
# 17   04-29                  0.242
# 18   04-30                  0.262
# 19   05-01                  0.262
# 20   05-03                  0.269
# 21   05-04                  0.278
# 22   05-05                  0.267
# 23   05-06                  0.266
# 24   05-08                  0.268
# 25   05-09                  0.267
# ...

# %%
mccann_2017 = pd.read_csv('csv_from_scrape/mccann_2017_df.csv')
mccann_2017.columns.values[1] = 'DATE'
mccann_2017.columns.values[2] = '2017 Batting Averages'
mccann_2017.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2017 Batting Averages
# 0   04-03                  0.000
# 1   04-04                  0.167
# 2   04-06                  0.200
# 3   04-08                  0.286
# 4   04-09                  0.278
# 5   04-11                  0.227
# 6   04-12                  0.200
# 7   04-14                  0.241
# 8   04-15                  0.267
# 9   04-18                  0.294
# 10  04-19                  0.289
# 11  04-20                  0.268
# 12  04-21                  0.311
# 13  04-23                  0.313
# 14  04-25                  0.288
# 15  04-26                  0.281
# 16  04-27                  0.279
# 17  04-29                  0.262
# 18  04-30                  0.279
# 19  05-01                  0.278
# 20  05-03                  0.280
# 21  05-04                  0.269
# 22  05-05                  0.280
# 23  05-06                  0.294
# 24  05-09                  0.281
# 25  05-11                  0.272
# 26  05-12                  0.281
# ...

# %%
frames = [dates, mccann_2005, mccann_2006, mccann_2007, mccann_2008, mccann_2009, mccann_2010, mccann_2011, 
          mccann_2012, mccann_2013, mccann_2014, mccann_2015, mccann_2016, mccann_2017]

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'], how='outer'), frames)

# %%
drops = ['Unnamed: 0_x', 'Unnamed: 0_y', 'Unnamed: 0']

# %%
mccann_batting = df_merged.drop(drops, axis = 1)

# %%
mccann_batting.to_csv('data_aggregated/mccann_batting.csv', index=False)
