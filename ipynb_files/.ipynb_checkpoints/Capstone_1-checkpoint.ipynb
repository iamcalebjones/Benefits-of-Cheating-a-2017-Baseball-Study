# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# is there data out there for continuously updated batting averages throughout the season? i'm interested in plotting updated batting average on top of bangs through the season.
#
# retrosheet.org has the most complete records i was able to find. the data i found was updated per game, so i scraped that and formatted a pandas dataframe for each player on the 2017 Astros that is found in this 'bangs' file that i import here.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
bangs = pd.read_csv('../astros_bangs_20200127.csv')

# %%
bangs.shape
# Out:
# (8274, 29)

# %%
bangs.head(25)
# Out:
#                        game_id  game_pk game_date opponent  final_away_runs  \
# 0   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 1   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 2   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 3   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 4   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 5   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 6   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 7   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 8   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 9   2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 10  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 11  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 12  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 13  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 14  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 15  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 16  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 17  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 18  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 19  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 20  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 21  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 22  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 23  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 24  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
#
#     final_home_runs  inning top_bottom           batter      at_bat_event  \
# 0                 3       1     bottom  George Springer          Home Run
# 1                 3       1     bottom  George Springer          Home Run
# 2                 3       1     bottom  George Springer          Home Run
# 3                 3       1     bottom  George Springer          Home Run
# 4                 3       1     bottom     Alex Bregman            Single
# 5                 3       1     bottom      Jose Altuve         Strikeout
# 6                 3       1     bottom      Jose Altuve         Strikeout
# 7                 3       1     bottom      Jose Altuve         Strikeout
# 8                 3       1     bottom      Jose Altuve         Strikeout
# 9                 3       1     bottom      Jose Altuve         Strikeout
# 10                3       1     bottom      Jose Altuve         Strikeout
# 11                3       1     bottom    Carlos Correa       Double Play
# 12                3       1     bottom    Carlos Correa       Double Play
# 13                3       2     bottom   Carlos Beltran         Strikeout
# 14                3       2     bottom   Carlos Beltran         Strikeout
# 15                3       2     bottom   Carlos Beltran         Strikeout
# 16                3       2     bottom   Carlos Beltran         Strikeout
# 17                3       2     bottom   Carlos Beltran         Strikeout
# 18                3       2     bottom     Josh Reddick            Single
# 19                3       2     bottom     Josh Reddick            Single
# 20                3       2     bottom     Josh Reddick            Single
# 21                3       2     bottom     Josh Reddick            Single
# 22                3       2     bottom     Josh Reddick            Single
# 23                3       2     bottom     Yuli Gurriel  Grounded Into DP
# 24                3       2     bottom     Yuli Gurriel  Grounded Into DP
#
#    pitch_type_code pitch_category has_bangs bangs call_code      description  \
# 0               SI             FB         n   NaN         B             Ball
# 1               SI             FB         n   NaN         F             Foul
# 2               SL             BR         n   NaN         B             Ball
# 3               SI             FB         n   NaN         E  In play, run(s)
# 4               FF             FB         n   NaN         D  In play, no out
# 5               SI             FB         n   NaN         B             Ball
# 6               SL             BR         y    1B         C    Called Strike
# 7               FF             FB         n   NaN         F             Foul
# 8               CH             CH         n   NaN         B             Ball
# 9               CH             CH         n   NaN         B             Ball
# 10              SL             BR         n   NaN         S  Swinging Strike
# 11              SI             FB         n   NaN         B             Ball
# 12              SI             FB         n   NaN         X  In play, out(s)
# 13              SI             FB         n   NaN         F             Foul
# 14              CU             BR         n   NaN         B             Ball
# 15              CU             BR         n   NaN         C    Called Strike
# 16              SI             FB         n   NaN         B             Ball
# 17              FF             FB         n   NaN         C    Called Strike
# 18              SI             FB         n   NaN         F             Foul
# 19              CH             CH         n   NaN         B             Ball
# 16  164cb4d8-c519-4261-85a7-bba6bff79128           136           117
# 17  164cb4d8-c519-4261-85a7-bba6bff79128           136           117
# 18  c7067557-1c37-41ba-b9df-97b7c1afd01b           136           117
# 19  c7067557-1c37-41ba-b9df-97b7c1afd01b           136           117
# 20  c7067557-1c37-41ba-b9df-97b7c1afd01b           136           117
# 21  c7067557-1c37-41ba-b9df-97b7c1afd01b           136           117
# 22  c7067557-1c37-41ba-b9df-97b7c1afd01b           136           117
# 23  67270cc6-8a86-4a04-a361-8b4a184f40bb           136           117
# 24  67270cc6-8a86-4a04-a361-8b4a184f40bb           136           117

# %%
bangs['game_date'][2500].split('/')
# Out:
# ['19', '5', '2017']

# %%
# format a better date column for future plotting work

better_dates = []
for i in range(len(bangs)):
    
    x = bangs['game_date'][i].split('/')
    
    if len(x[0]) == 1 and len(x[1]) == 1:
        better_dates.append('0' + x[1] + '-0' + x[0])
        
    elif len(x[0]) > 1 and len(x[1]) == 1:
        better_dates.append('0' + x[1] + '-' + x[0])
        
    elif len(x[0]) == 1 and len(x[1]) > 1:
        better_dates.append(x[1] + '-0' + x[0])
        
    else:
        better_dates.append(x[1] + '-' + x[0])

# %%
# add new date column to df, then save it as new name

bangs['DATE'] = pd.Series(better_dates)

# %%
bangs.tail()
# Out:
#                          game_id  game_pk  game_date opponent  \
# 8269  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8270  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8271  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8272  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8273  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
#
#       final_away_runs  final_home_runs  inning top_bottom       batter  \
# 8269                7                5       9     bottom  Jose Altuve
# 8270                7                5       9     bottom  Jose Altuve
# 8271                7                5       9     bottom  Jose Altuve
# 8272                7                5       9     bottom  Jose Altuve
# 8273                7                5       9     bottom  Jose Altuve
#
#      at_bat_event pitch_type_code pitch_category has_bangs bangs call_code  \
# 8269    Strikeout              FF             FB         n   NaN         C
# 8270    Strikeout              FF             FB         n   NaN         C
# 8271    Strikeout              FF             FB         n   NaN         B
# 8272    Strikeout              FS             FB         n   NaN         B
# 8273    Strikeout              FF             FB         n   NaN         S
#
#           description on_1b on_2b on_3b   youtube_id  pitch_youtube_seconds  \
# 8269    Called Strike     f     f     f  oIChAX54tS4                  14176
# 8270    Called Strike     f     f     f  oIChAX54tS4                  14200
# 8271             Ball     f     f     f  oIChAX54tS4                  14229
# 8272             Ball     f     f     f  oIChAX54tS4                  14265
# 8273  Swinging Strike     f     f     f  oIChAX54tS4                  14303
#
#                                             youtube_url  \
# 8269  https://www.youtube.com/watch?v=oIChAX54tS4&t=...
# 8270  https://www.youtube.com/watch?v=oIChAX54tS4&t=...
# 8271  https://www.youtube.com/watch?v=oIChAX54tS4&t=...
# 8272  https://www.youtube.com/watch?v=oIChAX54tS4&t=...
# 8273  https://www.youtube.com/watch?v=oIChAX54tS4&t=...
#
#                 pitch_datetime game_pitch_id  event_number  \
# 8269  24/9/2017 22:56:22-05:05  170925035627           694
# 8270  24/9/2017 22:56:46-05:05  170925035651           695
# 8271  24/9/2017 22:57:15-05:05  170925035720           696
# 8272  24/9/2017 22:57:51-05:05  170925035756           697
# 8273  24/9/2017 22:58:29-05:05  170925035834           698
#
#                               pitch_playid  \
# 8269  3fb6c165-a172-441f-811c-e6f69b87d184
# 8270  b5be7076-a036-4b98-a988-d644da58f175
# 8271  861ed82a-579c-4860-addf-3eb43db80bf3
# 8272  fab219e6-64db-4ae8-8e0b-4e040a72dc29
# 8273  121bea48-7a5d-44e5-b71a-0f16033fc71a
#
#                               atbat_playid  away_team_id  home_team_id   DATE
# 8269  121bea48-7a5d-44e5-b71a-0f16033fc71a           108           117  09-24
# 8270  121bea48-7a5d-44e5-b71a-0f16033fc71a           108           117  09-24
# 8271  121bea48-7a5d-44e5-b71a-0f16033fc71a           108           117  09-24
# 8272  121bea48-7a5d-44e5-b71a-0f16033fc71a           108           117  09-24
# 8273  121bea48-7a5d-44e5-b71a-0f16033fc71a           108           117  09-24

# %%
bangs.to_csv('../bangs_file_better_date.csv', index=False)

# %%
# test import dataframe with new date column

bangs_better_date = pd.read_csv('../bangs_file_better_date.csv')
bangs_better_date.head() # this dataframe has a new column with better date formatting, last column on the far right
# Out:
#                       game_id  game_pk game_date opponent  final_away_runs  \
# 0  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 1  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 2  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 3  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
# 4  2017_04_03_seamlb_houmlb_1   490111  3/4/2017      SEA                0
#
#    final_home_runs  inning top_bottom           batter at_bat_event  \
# 0                3       1     bottom  George Springer     Home Run
# 1                3       1     bottom  George Springer     Home Run
# 2                3       1     bottom  George Springer     Home Run
# 3                3       1     bottom  George Springer     Home Run
# 4                3       1     bottom     Alex Bregman       Single
#
#   pitch_type_code pitch_category has_bangs bangs call_code      description  \
# 0              SI             FB         n   NaN         B             Ball
# 1              SI             FB         n   NaN         F             Foul
# 2              SL             BR         n   NaN         B             Ball
# 3              SI             FB         n   NaN         E  In play, run(s)
# 4              FF             FB         n   NaN         D  In play, no out
#
#   on_1b on_2b on_3b   youtube_id  pitch_youtube_seconds  \
# 0     f     f     f  af5e55Cc8ZA                   1473
# 1     f     f     f  af5e55Cc8ZA                   1489
# 2     f     f     f  af5e55Cc8ZA                   1512
# 3     f     f     f  af5e55Cc8ZA                   1529
# 4     f     f     f  af5e55Cc8ZA                   1580
#
#                                          youtube_url           pitch_datetime  \
# 0  https://www.youtube.com/watch?v=af5e55Cc8ZA&t=...  3/4/2017 19:24:41-05:05
# 1  https://www.youtube.com/watch?v=af5e55Cc8ZA&t=...  3/4/2017 19:24:57-05:05
# 2  https://www.youtube.com/watch?v=af5e55Cc8ZA&t=...  3/4/2017 19:25:20-05:05
# 3  https://www.youtube.com/watch?v=af5e55Cc8ZA&t=...  3/4/2017 19:25:37-05:05
# 4  https://www.youtube.com/watch?v=af5e55Cc8ZA&t=...  3/4/2017 19:26:28-05:05
#
#   game_pitch_id  event_number                          pitch_playid  \
# 0  170404002442            32  ca9ed282-a9c3-45a6-ac10-d216fae7ce8b
# 1  170404002458            33  7f89900c-faed-485c-a6b6-41c0a2b1c26f
# 2  170404002521            34  6c875b0c-b4e3-4521-b1c0-447ee785bff9
# 3  170404002538            35  1421aabe-7063-4902-9a46-4b2c239394cb
# 4  170404002636            40  3a7c0b8b-3b0c-4832-90d0-5d8425d0b995
#
#                            atbat_playid  away_team_id  home_team_id   DATE
# 0  1421aabe-7063-4902-9a46-4b2c239394cb           136           117  04-03
# 1  1421aabe-7063-4902-9a46-4b2c239394cb           136           117  04-03
# 2  1421aabe-7063-4902-9a46-4b2c239394cb           136           117  04-03
# 3  1421aabe-7063-4902-9a46-4b2c239394cb           136           117  04-03
# 4  3a7c0b8b-3b0c-4832-90d0-5d8425d0b995           136           117  04-03

# %% [markdown]
# I'm going to create some lists of the unique values in columns of interest.

# %% [markdown]
# Some ideas for next steps are to see what percentage of pitches had bangs for the entire data set, and then similarly for each batter.

# %%
batters = list(pd.unique(bangs_better_date['batter']))
batters.sort()
batters
# Out:
# ['AJ Reed',
#  'Alex Bregman',
#  'Brian McCann',
#  'Cameron Maybin',
#  'Carlos Beltran',
#  'Carlos Correa',
#  'Derek Fisher',
#  'Evan Gattis',
#  'George Springer',
#  'J.D. Davis',
#  'Jake Marisnick',
#  'Jose Altuve',
#  'Josh Reddick',
#  'Juan Centeno',
#  'Marwin Gonzalez',
#  'Max Stassi',
#  'Norichika Aoki',
#  'Tony Kemp',
#  'Tyler White',
#  'Yuli Gurriel']

# %%
percent_bangs_by_batter = [] # populate a list with tuples of names and percent bangs so it can be sorted
percent_bangs_by_batter_dict = {} # also a dictionary for easy searching...
for i in batters:
    bang_pitches = ((bangs_better_date[(bangs_better_date.batter == i)]).has_bangs.values == 'y').sum()
    total_pitches = len((bangs_better_date[(bangs_better_date.batter == i)]))
    percent_bangs = (bang_pitches/total_pitches) * 100
    percent_bangs_by_batter.append((i, round(percent_bangs, 2)))
    percent_bangs_by_batter_dict[i] = round(percent_bangs, 2)

percent_bangs_by_batter = sorted(percent_bangs_by_batter, key=lambda x: x[1])

# %%
batters_pitches = [] # populate a list with tuples of names and total number of pitches seen so it can be sorted
batters_pitches_dict = {} # also a dictionary for easy searching...
for i in batters:
    total_pitches = len((bangs_better_date[(bangs_better_date.batter == i)]))
    batters_pitches.append((i, total_pitches))
    batters_pitches_dict[i] = total_pitches
    
batters_pitches = sorted(batters_pitches, key=lambda x: x[1])

# %%
batters_bangs = [] # populate a list with tuples of names and total number of pitches with bangs so it can be sorted
batters_bangs_dict = {} # also a dictionary for easy searching...
for i in batters:
    bang_pitches = ((bangs_better_date[(bangs_better_date.batter == i)]).has_bangs.values == 'y').sum()
    batters_bangs.append((i, bang_pitches))
    batters_bangs_dict[i] = bang_pitches

batters_bangs = sorted(batters_bangs, key=lambda x: x[1])

# %%
percent_bangs_by_batter # percentage of pitches seen by each batter that had bangs
# Out:
# [('Tony Kemp', 0.0),
#  ('Jose Altuve', 2.77),
#  ('Josh Reddick', 3.86),
#  ('Norichika Aoki', 6.13),
#  ('Derek Fisher', 7.58),
#  ('Brian McCann', 8.88),
#  ('AJ Reed', 14.81),
#  ('George Springer', 14.9),
#  ('Carlos Correa', 16.33),
#  ('Alex Bregman', 16.62),
#  ('Evan Gattis', 16.63),
#  ('Yuli Gurriel', 17.91),
#  ('Carlos Beltran', 18.11),
#  ('Marwin Gonzalez', 18.94),
#  ('Juan Centeno', 20.0),
#  ('Jake Marisnick', 22.8),
#  ('Cameron Maybin', 23.21),
#  ('Max Stassi', 25.0),
#  ('Tyler White', 26.42),
#  ('J.D. Davis', 28.57)]

# %%
batters_pitches # number of pitches seen by each batter
# Out:
# [('Tony Kemp', 23),
#  ('AJ Reed', 27),
#  ('J.D. Davis', 49),
#  ('Max Stassi', 52),
#  ('Cameron Maybin', 56),
#  ('Juan Centeno', 65),
#  ('Tyler White', 106),
#  ('Derek Fisher', 211),
#  ('Norichika Aoki', 261),
#  ('Jake Marisnick', 364),
#  ('Evan Gattis', 427),
#  ('Brian McCann', 507),
#  ('Carlos Correa', 594),
#  ('Yuli Gurriel', 670),
#  ('Josh Reddick', 725),
#  ('Carlos Beltran', 762),
#  ('Marwin Gonzalez', 776),
#  ('Alex Bregman', 800),
#  ('Jose Altuve', 866),
#  ('George Springer', 933)]

# %%
batters_bangs # number of pitches seen with bangs by each batter
# Out:
# [('Tony Kemp', 0),
#  ('AJ Reed', 4),
#  ('Cameron Maybin', 13),
#  ('Juan Centeno', 13),
#  ('Max Stassi', 13),
#  ('J.D. Davis', 14),
#  ('Derek Fisher', 16),
#  ('Norichika Aoki', 16),
#  ('Jose Altuve', 24),
#  ('Josh Reddick', 28),
#  ('Tyler White', 28),
#  ('Brian McCann', 45),
#  ('Evan Gattis', 71),
#  ('Jake Marisnick', 83),
#  ('Carlos Correa', 97),
#  ('Yuli Gurriel', 120),
#  ('Alex Bregman', 133),
#  ('Carlos Beltran', 138),
#  ('George Springer', 139),
#  ('Marwin Gonzalez', 147)]

# %%
percent_bangs_by_batter_dict['Jose Altuve']
# Out:
# 2.77

# %%
# select batters who had higher than 15% bangs and more than 300 pitches

for i in batters:
    if percent_bangs_by_batter_dict[i] > 15 and batters_pitches_dict[i] > 300:
        print(i)
# Out:
# Alex Bregman
# Carlos Beltran
# Carlos Correa
# Evan Gattis
# Jake Marisnick
# Marwin Gonzalez
# Yuli Gurriel

# %% [markdown]
# ### Next, find a way to quantify success at the plate (so per at bat, sorting by at bats with bangs and at bats without bangs), be that just getting on base, or getting a hit. Probably just if they get on base, that will be a success, and if the hitter is bats and it is an out, that will be a failure. Also, need to distinguish between if contact was made on pitches with bangs vs at bats with bangs but not specific pitches with bangs...

# %%
game_dates = list(pd.unique(bangs_better_date['game_date']))
len(game_dates)
# Out:
# 58

# %%
pitch_types = list(pd.unique(bangs_better_date['pitch_type_code']))
pitch_types
# Out:
# ['SI', 'SL', 'FF', 'CH', 'CU', 'FC', 'FT', 'FS', 'UN', 'KC', 'PO', 'EP']

# %%
pitch_category = list(pd.unique(bangs_better_date['pitch_category']))
pitch_category
# Out:
# ['FB', 'BR', 'CH', 'OT']

# %%
call_code = list(pd.unique(bangs_better_date['call_code']))
call_code
# Out:
# ['B', 'F', 'E', 'D', 'C', 'S', 'X', '*B', 'W', 'L', 'T', nan, 'M', 'P']

# %% [markdown]
# ## Next will be to group by batter and perform similar calculations on each player.

# %%
altuve_bangs = bangs[(bangs['batter'] == 'Jose Altuve') & (bangs['description'] == 'In play, run(s)')]# & (bangs['has_bangs'] == 'y')]

# %%
altuve_bangs.to_csv('../data_aggregated/altuve_bangs.csv', index = False)

# %%
len(bangs[(bangs['batter'] == 'Jose Altuve') & (bangs['has_bangs'] == 'n') & (bangs['description'] == 'In play, run(s)')])
# Out:
# 21

# %%
altuve_bangs
# Out:
#                          game_id  game_pk  game_date opponent  \
# 938   2017_04_17_anamlb_houmlb_1   490288  17/4/2017      ANA
# 993   2017_04_17_anamlb_houmlb_1   490288  17/4/2017      ANA
# 1159  2017_04_19_anamlb_houmlb_1   490317  19/4/2017      ANA
# 1626  2017_04_29_oakmlb_houmlb_1   490454  29/4/2017      OAK
# 1679  2017_05_02_texmlb_houmlb_1   490499   2/5/2017      TEX
# 2131  2017_05_09_atlmlb_houmlb_1   490583   9/5/2017      ATL
# 2682  2017_05_22_detmlb_houmlb_1   490766  22/5/2017      DET
# 2857  2017_05_23_detmlb_houmlb_1   490775  23/5/2017      DET
# 3112  2017_05_28_balmlb_houmlb_1   490846  28/5/2017      BAL
# 3537  2017_06_11_anamlb_houmlb_1   491042  11/6/2017      ANA
# 4132  2017_06_28_oakmlb_houmlb_1   491275  28/6/2017      OAK
# 4341  2017_06_29_oakmlb_houmlb_1   491289  29/6/2017      OAK
# 4404  2017_06_30_nyamlb_houmlb_1   491301  30/6/2017      NYY
# 4502  2017_06_30_nyamlb_houmlb_1   491301  30/6/2017      NYY
# 4886  2017_07_15_minmlb_houmlb_1   491455  15/7/2017      MIN
# 5483  2017_07_31_tbamlb_houmlb_1   491678  31/7/2017       TB
# 5794  2017_08_03_tbamlb_houmlb_1   491722   3/8/2017       TB
# 6269  2017_08_06_tormlb_houmlb_1   491767   6/8/2017      TOR
# 6527  2017_08_18_oakmlb_houmlb_1   491922  18/8/2017      OAK
# 7469  2017_09_15_seamlb_houmlb_1   492307  15/9/2017      SEA
# 7655  2017_09_19_chamlb_houmlb_1   492351  19/9/2017      CWS
# 7717  2017_09_19_chamlb_houmlb_1   492351  19/9/2017      CWS
# 7833  2017_09_20_chamlb_houmlb_1   492366  20/9/2017      CWS
#
#       final_away_runs  final_home_runs  inning top_bottom       batter  \
# 938                 0                3       3     bottom  Jose Altuve
# 993                 0                3       8     bottom  Jose Altuve
# 1159                1                5       1     bottom  Jose Altuve
# 1626                2                1       8     bottom  Jose Altuve
# 1679                7                8       4     bottom  Jose Altuve
# 2131                3                8       1     bottom  Jose Altuve
# 2682                0                1       1     bottom  Jose Altuve
# 2857                2                6       3     bottom  Jose Altuve
# 3112                4                8       2     bottom  Jose Altuve
# 3537               12                6       4     bottom  Jose Altuve
# 4132                8               11       2     bottom  Jose Altuve
# 4341                1                6       6     bottom  Jose Altuve
# 4404               13                4       1     bottom  Jose Altuve
# 4502               13                4       8     bottom  Jose Altuve
# 4886                4                2       3     bottom  Jose Altuve
# 5483                7               14       2     bottom  Jose Altuve
# 5794                5                3       3     bottom  Jose Altuve
# 6269                6                7       5     bottom  Jose Altuve
# 6527                1                3       3     bottom  Jose Altuve
# 7469                2                5       1     bottom  Jose Altuve
# 7655                1                3       4     bottom  Jose Altuve
# 7717                1                3       8     bottom  Jose Altuve
# 7833                3                4       7     bottom  Jose Altuve
#
#      at_bat_event pitch_type_code pitch_category has_bangs bangs call_code  \
# 938       Sac Fly              FF             FB         n   NaN         E
# 993        Double              FF             FB         y    1B         E
# 1159       Single              SL             BR         n   NaN         E
# 1626     Home Run              FF             FB         n   NaN         E
# 1679     Home Run              SI             FB         n   NaN         E
# 2131       Single              FT             FB         n   NaN         E
# 2682       Double              CH             CH         n   NaN         E
# 2857  Field Error              FF             FB         n   NaN         E
# 3112       Single              FC             FB         n   NaN         E
# 3537       Single              FS             FB         n   NaN         E
# 4132       Single              CU             BR         n   NaN         E
# 4341       Double              SL             BR         n   NaN         E
# 4404      Sac Fly              SL             BR         n   NaN         E
# 4502    Groundout              FC             FB         n   NaN         E
# 4886     Home Run              FT             FB         n   NaN         E
# 5483       Single              KC             BR         n   NaN         E
# 5794     Home Run              CH             CH         n   NaN         E
# 6269       Single              FT             FB         n   NaN         E
# 6527     Home Run              FF             FB         n   NaN         E
# 7469       Single              FF             FB         n   NaN         E
# 7655     Home Run              FF             FB         n   NaN         E
# 7717    Groundout              CH             CH         n   NaN         E
# 7833       Single              SL             BR         y    1B         E
#
#           description on_1b on_2b on_3b   youtube_id  pitch_youtube_seconds  \
# 938   In play, run(s)     t     f     t  iP2zDfaBz9w                   4443
# 993   In play, run(s)     f     t     f  iP2zDfaBz9w                   9239
# 1159  In play, run(s)     f     f     t  jp1YLsKpItY                   1445
# 1626  In play, run(s)     f     f     f  yaR6uZ6Ysys                   9178
# 1679  In play, run(s)     t     f     f  fVziGYabT2E                   4473
# 2131  In play, run(s)     t     f     t  CrTuuds5FTY                   1256
# 2682  In play, run(s)     t     f     f  agAm8myQGq8                   1509
# 2857  In play, run(s)     f     t     f  RGwHoQrhISw                   4194
# 3112  In play, run(s)     f     f     t  oM0yZ4bcJ4Y                   4006
# 3537  In play, run(s)     t     f     t  CqFZRiw7xPQ                   6395
# 4132  In play, run(s)     f     f     t  uQ96ejh3eoo                   3216
# 4341  In play, run(s)     t     f     f  sploj405Igw                   8127
# 4404  In play, run(s)     f     f     t  nVUSW0y7v1U                   1531
# 3112  f2324898-a618-442a-9a70-dc776fb21f30           110           117  05-28
# 3537  1e4506f2-f387-40c5-aca5-c92cb725e932           108           117  06-11
# 4132  9997e1fe-0429-4428-ab14-525db5bf5340           133           117  06-28
# 4341  2dbd7bc0-f7e1-498a-a74d-e92d66dc05ce           133           117  06-29
# 4404  f4de16ca-54e0-4973-a202-16bdb55bffd9           147           117  06-30
# 4502  7fd650e2-e5c2-4599-b362-2c9812214c20           147           117  06-30
# 4886  afba301d-8161-4849-95c2-34e10b26b323           142           117  07-15
# 5483  1ea8cd14-0d87-4b32-b58b-152df191de98           139           117  07-31
# 5794  00de8605-6e04-4370-822b-c8e5e74d78b8           139           117  08-03
# 6269  f8856b2f-ceef-4c20-9510-fd18f94e4f96           141           117  08-06
# 6527  c4b45632-aab1-46dd-9d98-75e439b6adbd           133           117  08-18
# 7469  3b140e63-30e1-4fbe-9d48-dd7fdb661f07           136           117  09-15
# 7655  47aaa7c8-2313-411a-8b5c-0547315e394b           145           117  09-19
# 7717  e5a240c0-866d-411d-8a56-19674c9ac4c2           145           117  09-19
# 7833  d4e53df9-e343-4be1-bb11-aa2e327ff143           145           117  09-20

# %%
events = list(pd.unique(bangs_better_date['at_bat_event']))
events
# Out:
# ['Home Run',
#  'Single',
#  'Strikeout',
#  'Double Play',
#  'Grounded Into DP',
#  'Catcher Interference',
#  'Flyout',
#  'Groundout',
#  'Lineout',
#  'Walk',
#  'Sac Fly',
#  'Field Error',
#  'Runner Out',
#  'Forceout',
#  'Pop Out',
#  'Fan interference',
#  'Double',
#  'Sac Bunt',
#  'Hit By Pitch',
#  'Strikeout - DP',
#  'Triple',
#  'Fielders Choice Out',
#  'Bunt Groundout',
#  'Batter Interference',
#  'Bunt Pop Out']

# %%
# define categories for each of the plate appearance events
# a successful event is getting on base (home run included, side effect of home run is scoring lol) or driving in a run
# a failed event is the at bat ending in an out
# a non-contributing event is anyting that wouldn't contribute the to batting average/at-bat tally

ab_success = ['Home Run',
              'Single',
              'Field Error',
              'Double',
              'Triple',
              'Sac Fly',
              'Sac Bunt']

ab_failure = ['Strikeout',
              'Double Play',
              'Grounded Into DP',
              'Flyout',
              'Groundout',
              'Lineout',
              'Runner Out',
              'Forceout',
              'Pop Out',
              'Sac Bunt',
              'Strikeout - DP',
              'Fielders Choice Out',
              'Bunt Groundout',
              'Bunt Pop Out']

ab_non_contribute = ['Catcher Interference',
                     'Walk',
                     'Fan interference',
                     'Hit By Pitch',
                     'Batter Interference']

# %%
descriptions = list(pd.unique(bangs_better_date['description']))
descriptions
# Out:
# ['Ball',
#  'Foul',
#  'In play, run(s)',
#  'In play, no out',
#  'Called Strike',
#  'Swinging Strike',
#  'In play, out(s)',
#  'Ball In Dirt',
#  'Swinging Strike (Blocked)',
#  'Foul Bunt',
#  'Foul Tip',
#  'Hit By Pitch',
#  'Foul (Runner Going)',
#  'Missed Bunt',
#  'Pitchout']

# %%
# define categories for each pitch description
# a successful description is anything that is either the batter getting on base, which does not contribute to ending the at bat (balls)
# a failed description is antying that ends the at bat (in play out) or contributes to its end (strikes, foul balls)
# a non-contributing description is a pitch at that does not contribute to the batting average calculation

desc_success = ['In play, run(s)',
                'In play, no out',
                'Ball',
                'Ball In Dirt',
                'Pitchout']

desc_failure = ['Called Strike',
                'Swinging Strike',
                'In play, out(s)',
                'Swinging Strike (Blocked)',
                'Missed Bunt',
                'Foul',
                'Foul Bunt',
                'Foul Tip',
                'Foul (Runner Going)']

desc_non_contribute = ['Hit By Pitch']

# %%
# test out building out evaluation metrics for at bats and per pitch

ab_dict = {'success': 0, 'failure': 0, 'na': 0}
desc_dict = {'success': 0, 'failure': 0, 'na': 0}

for i in altuve_bangs['at_bat_event']:
    if i in ab_success:
        ab_dict['success'] += 1
    elif i in ab_failure:
        ab_dict['failure'] += 1
    else:
        ab_dict['na'] += 1

for i in altuve_bangs['description']:
    if i in desc_success:
        desc_dict['success'] += 1
    elif i in desc_failure:
        desc_dict['failure'] += 1
    else:
        desc_dict['na'] += 1

# %%
altuve_bang_success = ab_dict['success'] / sum(ab_dict.values())
round(altuve_bang_success, 2)
# Out:
# 0.21

# %%
altuve_desc_success = desc_dict['success'] / sum(desc_dict.values())
round(altuve_desc_success, 2)
# Out:
# 0.42

# %%
batters_to_evaluate = ['Jose Altuve',
                       'Alex Bregman',
                       'Carlos Beltran',
                       'Carlos Correa',
                       'Evan Gattis',
                       'Jake Marisnick',
                       'Marwin Gonzalez',
                       'Yuli Gurriel']

# %%
'''the AB metrics are a little more realistic of a metric, because they describe how the at bat ended, either in
getting on base and potentially scoring a run, or in getting put out.

The per pitch metrics are a little more misleading because lets say a batter like Alex Bregman fouls off 5 pitches
and then homers, there would be 5 failures and then one success in the successful AB. So i might drop the per pitch
metrics altogether.'''

evaluation_metrics = ['Pitches with Bangs',
                      'Total Pitches',
                      'Percent Bangs',
                      'Bang AB Success Rate',
                      'Clean AB Success Rate',
                      'Bang AB Failure Rate',
                      'Clean AB Failure Rate',
                      'Bang AB Runs Generated',
                      'Clean AB Runs Generated',
                      'Bang Pitch Success Rate',
                      'Clean Pitch Succes Rate',
                      'Bang Pitch Failure Rate',
                      'Clean Pitch Failure Rate',
                      'Bang Pitch Runs Generated',
                      'Clean Pitch Runs Generated']

# %%
# and putting those into a loop for each player...

# batters_to_evaluate = ['Jose Altuve']

player_evaluation_df = pd.DataFrame()
player_evaluation_df['Metric'] = evaluation_metrics


for name in batters_to_evaluate:
    player_bangs = bangs[(bangs['batter'] == name) & (bangs['has_bangs'] == 'y')]
    player_no_bangs = bangs[(bangs['batter'] == name) & (bangs['has_bangs'] == 'n')]
    
    # initialize dictionaries for successes and failures of bangs and no bangs at bats and pitches
    bang_ab_dict = {'success': 0, 'failure': 0, 'na': 0}
    bang_pitch_dict = {'success': 0, 'failure': 0, 'na': 0}
    no_bang_ab_dict = {'success': 0, 'failure': 0, 'na': 0}
    no_bang_pitch_dict = {'success': 0, 'failure': 0, 'na': 0}
    
    # loop for at-bats with bangs
    for i in player_bangs['at_bat_event']:
        if i in ab_success:
            bang_ab_dict['success'] += 1
        elif i in ab_failure:
            bang_ab_dict['failure'] += 1
        else:
            bang_ab_dict['na'] += 1

    # loop for pitches with bangs
    for i in player_bangs['description']:
        if i in desc_success:
            bang_pitch_dict['success'] += 1
        elif i in desc_failure:
            bang_pitch_dict['failure'] += 1
        else:
            bang_pitch_dict['na'] += 1
            
    # loop for at-bats without bangs
    for i in player_no_bangs['at_bat_event']:
        if i in ab_success:
            no_bang_ab_dict['success'] += 1
        elif i in ab_failure:
            no_bang_ab_dict['failure'] += 1
        else:
            no_bang_ab_dict['na'] += 1
    
    # loop for pitches without bangs
    for i in player_no_bangs['description']:
        if i in desc_success:
            no_bang_pitch_dict['success'] += 1
        elif i in desc_failure:
            no_bang_pitch_dict['failure'] += 1
        else:
            no_bang_pitch_dict['na'] += 1
            
            
            
    # calculate metrics, populate a list, put list in pandas dataframe
    
    # bang_ab_success - an at-bat with bangs that was successful
    bang_ab_success = round((bang_ab_dict['success'] / sum(bang_ab_dict.values())) * 100, 2)
    
    # clean_ab_success - an at-bat without bangs that was successful
    clean_ab_success = round((no_bang_ab_dict['success'] / sum(no_bang_ab_dict.values())) * 100, 2)
    
    # bang_ab_failure - an at-bat with bangs that was an out
    bang_ab_failure = round((bang_ab_dict['failure'] / sum(bang_ab_dict.values())) * 100, 2)
    
    # clean_ab_failure - an at-bat without bangs that was an out
    clean_ab_failure = round((no_bang_ab_dict['failure'] / sum(no_bang_ab_dict.values())) * 100, 2)
    
    # bang_ab_runs_generated - how many at-bats with bangs resulted in runs being scored (these are effectively RBIs)
    # (homer, single + runs scored, double + runs etc...)
    # loop through some boolean indexing and populate an accumulator
    bang_ab_runs_generated = 0
    for i in ab_success:
        bang_ab_runs_generated += (len(player_bangs[(player_bangs['at_bat_event'] == i) & (player_bangs['description'] == 'In play, run(s)')]))
    
    # clean_ab_runs_generated - how many at-bats without bangs resulted in runs being scored (these are effectively RBIs)
    # (homer, single + runs scored, double + runs etc...)
    # same idea, loop and accumulate
    clean_ab_runs_generated = 0
    for i in ab_success:
        clean_ab_runs_generated += (len(player_no_bangs[(player_no_bangs['at_bat_event'] == i) & (player_no_bangs['description'] == 'In play, run(s)')]))
        
    # bang_pitch_success - successful pitches with bangs
    bang_pitch_success = round((bang_pitch_dict['success'] / sum(bang_pitch_dict.values())) * 100, 2)
    
    # clean_pitch_success - successful pitches without bangs
    clean_pitch_success = round((no_bang_pitch_dict['success'] / sum(no_bang_pitch_dict.values())) * 100, 2)
    
    # bang_pitch_failure - failure pitches with bangs
    bang_pitch_failure = round((bang_pitch_dict['failure'] / sum(bang_pitch_dict.values())) * 100, 2)
    
    # clean_pitch_failure - successful pitches without bangs
    clean_pitch_failure = round((no_bang_pitch_dict['failure'] / sum(no_bang_pitch_dict.values())) * 100, 2)
    
    # bang_pitch_runs_generated - how many pitches with bangs resulted in runs being scored (runs from fielding errors)
    bang_pitch_runs_generated = (len(player_bangs[player_bangs['description'] == 'In play, run(s)']))
    
    # clean_pitch_runs_generated - how many pitches without bangs resulted in runs being scored
    # (in play + run(s))
    # same idea, loop and accumulate
    clean_pitch_runs_generated = (len(player_no_bangs[player_no_bangs['description'] == 'In play, run(s)']))
        
    # put the calculated metrics into a list, put list into dataframe of players
    metric = [batters_bangs_dict[name], batters_pitches_dict[name], percent_bangs_by_batter_dict[name], bang_ab_success, clean_ab_success, bang_ab_failure, clean_ab_failure, bang_ab_runs_generated, 
              clean_ab_runs_generated, bang_pitch_success, clean_pitch_success, bang_pitch_failure, 
              clean_pitch_failure, int(bang_pitch_runs_generated), clean_pitch_runs_generated]
    
    player_evaluation_df[name] = metric

# %%
player_evaluation_df
# Out:
#                         Metric  Jose Altuve  Alex Bregman  Carlos Beltran  \
# 0           Pitches with Bangs        24.00        133.00          138.00
# 1                Total Pitches       866.00        800.00          762.00
# 2                Percent Bangs         2.77         16.62           18.11
# 3         Bang AB Success Rate        25.00         33.08           20.29
# 4        Clean AB Success Rate        20.67         20.54           22.92
# 5         Bang AB Failure Rate        66.67         54.89           73.91
# 6        Clean AB Failure Rate        65.68         61.77           67.47
# 7       Bang AB Runs Generated         2.00          7.00            0.00
# 8      Clean AB Runs Generated        19.00         13.00           10.00
# 9      Bang Pitch Success Rate        41.67         53.38           33.33
# 10     Clean Pitch Succes Rate        41.81         43.93           42.47
# 11     Bang Pitch Failure Rate        54.17         46.62           66.67
# 12    Clean Pitch Failure Rate        57.72         56.07           57.37
# 13   Bang Pitch Runs Generated         2.00          7.00            1.00
# 14  Clean Pitch Runs Generated        21.00         14.00           11.00
#
#     Carlos Correa  Evan Gattis  Jake Marisnick  Marwin Gonzalez  Yuli Gurriel
# 0           97.00        71.00           83.00           147.00        120.00
# 1          594.00       427.00          364.00           776.00        670.00
# 2           16.33        16.63           22.80            18.94         17.91
# 3           25.77        21.13           19.28            13.61         32.50
# 4           26.56        20.22           20.28            25.28         26.91
# 5           64.95        69.01           69.88            78.23         57.50
# 6           59.56        63.76           67.26            60.89         66.18
# 7            3.00         1.00            4.00             2.00          5.00
# 8           13.00         9.00            8.00            18.00         16.00
# 9           49.48        54.93           43.37            44.90         51.67
# 10          46.88        41.57           38.79            44.52         42.55
# 11          50.52        45.07           56.63            55.10         47.50
# 12          52.92        58.43           60.50            55.33         57.09
# 13           4.00         1.00            4.00             2.00          5.00
# 14          14.00         9.00            8.00            18.00         17.00

# %% [markdown]
# The difference between AB runs generated and pitch runs generated (bang and clean) is due to sac events, sac fly, sac bunt.

# %%
list(player_evaluation_df.columns).index('Alex Bregman')
# Out:
# 2

# %%
test = ['a', 'b', 'c']
test
# Out:
# ['a', 'b', 'c']

# %%
test2 = ['d', 'e', 'f']
test2
# Out:
# ['d', 'e', 'f']

# %%
[test.append(i) for i in test2]
test
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']
