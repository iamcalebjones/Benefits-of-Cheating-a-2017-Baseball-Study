# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
altuve_batting = pd.read_csv('../data_aggregated/altuve_batting.csv')

# %%
altuve_batting.fillna(method = 'ffill', inplace=True)

# %%
altuve_bangs = pd.read_csv('../data_aggregated/altuve_bangs.csv')

# %%
altuve_bangs
# Out:
#                        game_id  game_pk  game_date opponent  final_away_runs  \
# 0   2017_04_03_seamlb_houmlb_1   490111   3/4/2017      SEA                0
# 1   2017_04_05_seamlb_houmlb_1   490133   5/4/2017      SEA                3
# 2   2017_04_05_seamlb_houmlb_1   490133   5/4/2017      SEA                3
# 3   2017_04_09_kcamlb_houmlb_1   490183   9/4/2017       KC                4
# 4   2017_04_17_anamlb_houmlb_1   490288  17/4/2017      ANA                0
# 5   2017_04_17_anamlb_houmlb_1   490288  17/4/2017      ANA                0
# 6   2017_04_19_anamlb_houmlb_1   490317  19/4/2017      ANA                1
# 7   2017_05_02_texmlb_houmlb_1   490499   2/5/2017      TEX                7
# 8   2017_06_10_anamlb_houmlb_1   491026  10/6/2017      ANA                1
# 9   2017_06_12_texmlb_houmlb_1   491059  12/6/2017      TEX                6
# 10  2017_06_12_texmlb_houmlb_1   491059  12/6/2017      TEX                6
# ...

# %%
altuve_batting.head()
# Out:
#     DATE  2011 Batting Averages  2012 Batting Averages  2013 Batting Averages  \
# 0  03-31                    NaN                    NaN                  0.500
# 1  04-01                    NaN                    NaN                  0.500
# 2  04-02                    NaN                    NaN                  0.375
# 3  04-03                    NaN                    NaN                  0.417
# 4  04-04                    NaN                    NaN                  0.417
#
#    2014 Batting Averages  2015 Batting Averages  2016 Batting Averages  \
# 0                    NaN                    NaN                    NaN
# 1                  0.500                    NaN                    NaN
# 2                  0.286                    NaN                    NaN
# 3                  0.300                    NaN                    NaN
# 4                  0.385                    NaN                    NaN
#
#    2017 Batting Averages
# 0                    NaN
# ...

# %%
pd.to_datetime(altuve_batting['DATE'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-57-c6d54e66aa00> in <module>
# ----> 1 pd.to_datetime(altuve_batting['DATE'])
#
# ...

# %%
months = mdates.MonthLocator()  # every month
months_fmt = mdates.DateFormatter('%m')

# %%
fig, ax = plt.subplots(figsize = (20, 8))

ax.plot(altuve_batting['DATE'], altuve_batting['2011 Batting Averages'], label = '2011')
ax.plot(altuve_batting['DATE'], altuve_batting['2012 Batting Averages'], label = '2012')
ax.plot(altuve_batting['DATE'], altuve_batting['2013 Batting Averages'], label = '2013')
ax.plot(altuve_batting['DATE'], altuve_batting['2014 Batting Averages'], label = '2014')
ax.plot(altuve_batting['DATE'], altuve_batting['2015 Batting Averages'], label = '2015')
ax.plot(altuve_batting['DATE'], altuve_batting['2016 Batting Averages'], label = '2016')
ax.plot(altuve_batting['DATE'], altuve_batting['2017 Batting Averages'], label = '2017', linewidth = 2.5, color='black')

ax.vlines(altuve_bangs['DATE'], ymin = 0, ymax = 0.5)

# format the ticks
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(months_fmt)

# round to nearest years.
datemin = np.datetime64(altuve_batting['DATE'][0], '%m-%d')
datemax = np.datetime64(altuve_batting['DATE'][-1], '%m-%d') + np.timedelta64(1, 'M')
ax.set_xlim(datemin, datemax)

ax.legend()
plt.title("Jose Altuve Career Batting Averages")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-63a09dd3290a> in <module>
#      16
#      17 # round to nearest years.
# ---> 18 datemin = np.datetime64(altuve_batting['DATE'][0], '%m-%d')
#      19 datemax = np.datetime64(altuve_batting['DATE'][-1], '%m-%d') + np.timedelta64(1, 'M')
#      20 ax.set_xlim(datemin, datemax)
#
# TypeError: Invalid datetime unit "%m-%d" in metadata
