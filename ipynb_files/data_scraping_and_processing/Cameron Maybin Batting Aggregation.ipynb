# %%
import pandas as pd
from functools import reduce

# %%
pd.set_option('display.max_rows', None)

# %%
dates = pd.read_csv('csv_from_scrape/baseball_dates_index.csv')

# %%
maybin_2007 = pd.read_csv('csv_from_scrape/maybin_2007_df.csv')
maybin_2007.columns.values[1] = 'DATE'
maybin_2007.columns.values[2] = '2007 Batting Averages'
maybin_2007.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2007 Batting Averages
# 0   08-17                  0.000
# 1   08-18                  0.286
# 2   08-19                  0.182
# 3   08-22                  0.267
# 4   08-23                  0.267
# 5   08-24                  0.211
# 6   08-26                  0.182
# 7   08-27                  0.208
# 8   08-30                  0.222
# 9   08-31                  0.200
# 10  09-01                  0.176
# 11  09-02                  0.158
# 12  09-04                  0.158
# 13  09-05                  0.158
# 14  09-06                  0.158
# 15  09-08                  0.158
# 16  09-09                  0.154
# 17  09-10                  0.154
# 18  09-11                  0.167
# 19  09-17                  0.167
# 20  09-23                  0.152
# 21  09-24                  0.152
# 22  09-25                  0.149
# 23  09-30                  0.143

# %%
maybin_2009 = pd.read_csv('csv_from_scrape/maybin_2009_df.csv')
maybin_2009.columns.values[1] = 'DATE'
maybin_2009.columns.values[2] = '2009 Batting Averages'
maybin_2009.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2009 Batting Averages
# 0   04-06                  0.250
# 1   04-07                  0.222
# 2   04-08                  0.222
# 3   04-10                  0.154
# 4   04-11                  0.235
# 5   04-12                  0.238
# 6   04-14                  0.240
# 7   04-15                  0.214
# 8   04-17                  0.219
# 9   04-18                  0.206
# 10  04-19                  0.206
# 11  04-20                  0.194
# 12  04-21                  0.211
# 13  04-22                  0.214
# 14  04-24                  0.217
# 15  04-25                  0.208
# 16  04-26                  0.189
# 17  04-28                  0.190
# 18  04-29                  0.190
# 19  04-30                  0.209
# 20  05-01                  0.211
# 21  05-02                  0.216
# 22  05-04                  0.208
# 23  05-06                  0.210
# 24  05-07                  0.202
# 25  05-10                  0.202
# 26  09-01                  0.200
# ...

# %%
maybin_2010 = pd.read_csv('csv_from_scrape/maybin_2010_df.csv')
maybin_2010.columns.values[1] = 'DATE'
maybin_2010.columns.values[2] = '2010 Batting Averages'
maybin_2010.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2010 Batting Averages
# 0   04-05                  0.000
# 1   04-07                  0.125
# 2   04-08                  0.250
# 3   04-09                  0.235
# 4   04-10                  0.286
# 5   04-11                  0.250
# 6   04-12                  0.276
# 7   04-13                  0.257
# 8   04-14                  0.263
# 9   04-15                  0.310
# 10  04-16                  0.298
# 11  04-17                  0.294
# 12  04-18                  0.309
# 13  04-20                  0.305
# 14  04-21                  0.302
# 15  04-22                  0.284
# 16  04-24                  0.278
# 17  04-26                  0.260
# 18  04-27                  0.263
# 19  04-28                  0.259
# 20  04-30                  0.247
# 21  05-01                  0.247
# 22  05-02                  0.247
# 23  05-04                  0.245
# 24  05-05                  0.238
# 25  05-06                  0.236
# 26  05-08                  0.231
# ...

# %%
maybin_2011 = pd.read_csv('csv_from_scrape/maybin_2011_df.csv')
maybin_2011.columns.values[1] = 'DATE'
maybin_2011.columns.values[2] = '2011 Batting Averages'
maybin_2011.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2011 Batting Averages
# 0    03-31                  0.400
# 1    04-02                  0.333
# 2    04-03                  0.250
# 3    04-05                  0.188
# 4    04-06                  0.167
# 5    04-08                  0.261
# 6    04-09                  0.222
# 7    04-10                  0.276
# 8    04-11                  0.258
# 9    04-12                  0.257
# 10   04-13                  0.243
# 11   04-14                  0.244
# 12   04-15                  0.250
# 13   04-16                  0.234
# 14   04-17                  0.250
# 15   04-18                  0.232
# 16   04-20                  0.224
# 17   04-20                  0.242
# 18   04-21                  0.246
# 19   04-22                  0.246
# 20   04-23                  0.260
# 21   04-24                  0.260
# 22   04-25                  0.247
# 23   04-26                  0.244
# 24   04-27                  0.233
# 25   04-29                  0.237
# ...

# %%
maybin_2012 = pd.read_csv('csv_from_scrape/maybin_2012_df.csv')
maybin_2012.columns.values[1] = 'DATE'
maybin_2012.columns.values[2] = '2012 Batting Averages'
maybin_2012.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2012 Batting Averages
# 0    04-05                  0.500
# 1    04-06                  0.375
# 2    04-07                  0.231
# 3    04-08                  0.294
# 4    04-10                  0.238
# 5    04-11                  0.208
# 6    04-12                  0.214
# 7    04-13                  0.226
# 8    04-14                  0.200
# 9    04-15                  0.175
# 10   04-16                  0.186
# 11   04-17                  0.170
# 12   04-19                  0.160
# 13   04-20                  0.167
# 14   04-21                  0.179
# 15   04-22                  0.183
# 16   04-24                  0.177
# 17   04-25                  0.167
# 18   04-26                  0.176
# 19   04-27                  0.194
# 20   04-28                  0.184
# 21   04-29                  0.177
# 22   04-30                  0.188
# 23   05-01                  0.183
# 24   05-02                  0.200
# 25   05-04                  0.202
# ...

# %%
maybin_2013 = pd.read_csv('csv_from_scrape/maybin_2013_df.csv')
maybin_2013.columns.values[1] = 'DATE'
maybin_2013.columns.values[2] = '2013 Batting Averages'
maybin_2013.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2013 Batting Averages
# 0   04-01                  0.000
# 1   04-03                  0.000
# 2   04-04                  0.000
# 3   04-05                  0.077
# 4   04-06                  0.059
# 5   04-09                  0.100
# 6   04-10                  0.083
# 7   04-11                  0.074
# 8   04-14                  0.067
# 9   04-15                  0.091
# 10  06-06                  0.132
# 11  06-07                  0.163
# 12  06-08                  0.149
# 13  06-09                  0.157

# %%
maybin_2014 = pd.read_csv('csv_from_scrape/maybin_2014_df.csv')
maybin_2014.columns.values[1] = 'DATE'
maybin_2014.columns.values[2] = '2014 Batting Averages'
maybin_2014.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2014 Batting Averages
# 0   04-27                  0.500
# 1   04-28                  0.375
# 2   04-29                  0.250
# 3   04-30                  0.267
# 4   05-02                  0.250
# 5   05-03                  0.316
# 6   05-04                  0.348
# 7   05-05                  0.360
# 8   05-07                  0.379
# 9   05-08                  0.375
# 10  05-09                  0.361
# 11  05-10                  0.341
# 12  05-13                  0.341
# 13  05-15                  0.318
# 14  05-15                  0.313
# 15  05-16                  0.288
# 16  05-18                  0.281
# 17  05-20                  0.276
# 18  05-21                  0.290
# 19  05-22                  0.288
# 20  05-23                  0.300
# 21  05-24                  0.284
# 22  05-25                  0.286
# 23  05-26                  0.286
# 24  05-27                  0.296
# 25  05-28                  0.310
# 26  05-30                  0.307
# ...

# %%
maybin_2015 = pd.read_csv('csv_from_scrape/maybin_2015_df.csv')
maybin_2015.columns.values[1] = 'DATE'
maybin_2015.columns.values[2] = '2015 Batting Averages'
maybin_2015.drop('Unnamed: 0', axis = 1)
# Out:
#       DATE  2015 Batting Averages
# 0    04-06                  0.000
# 1    04-07                  0.333
# 2    04-08                  0.167
# 3    04-10                  0.182
# 4    04-11                  0.167
# 5    04-13                  0.133
# 6    04-15                  0.167
# 7    04-17                  0.143
# 8    04-18                  0.115
# 9    04-19                  0.138
# 10   04-21                  0.147
# 11   04-24                  0.139
# 12   04-25                  0.135
# 13   04-27                  0.135
# 14   04-28                  0.175
# 15   05-01                  0.175
# 16   05-02                  0.209
# 17   05-03                  0.222
# 18   05-04                  0.208
# 19   05-05                  0.231
# 20   05-06                  0.232
# 21   05-08                  0.220
# 22   05-09                  0.238
# 23   05-10                  0.239
# 24   05-11                  0.229
# 25   05-12                  0.225
# ...

# %%
maybin_2016 = pd.read_csv('csv_from_scrape/maybin_2016_df.csv')
maybin_2016.columns.values[1] = 'DATE'
maybin_2016.columns.values[2] = '2016 Batting Averages'
maybin_2016.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2016 Batting Averages
# 0   05-16                  0.000
# 1   05-17                  0.667
# 2   05-18                  0.556
# 3   05-20                  0.615
# 4   05-21                  0.647
# 5   05-22                  0.600
# 6   05-23                  0.583
# 7   05-24                  0.571
# 8   05-25                  0.545
# 9   05-27                  0.528
# 10  05-28                  0.475
# 11  05-29                  0.465
# 12  05-30                  0.435
# 13  05-31                  0.429
# 14  06-01                  0.415
# 15  06-02                  0.414
# 16  06-03                  0.403
# 17  06-04                  0.418
# 18  06-05                  0.414
# 19  06-06                  0.419
# 20  06-07                  0.419
# 21  06-10                  0.410
# 22  06-11                  0.386
# 23  06-12                  0.375
# 24  06-13                  0.372
# 25  06-14                  0.379
# 26  06-15                  0.364
# ...

# %%
maybin_2017_1 = pd.read_csv('csv_from_scrape/maybin_2017_1_df.csv')
maybin_2017_1.columns.values[1] = 'DATE'
maybin_2017_1.columns.values[2] = '2017 Batting Averages 1'
maybin_2017_1.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2017 Batting Averages 1
# 0   04-03                    0.000
# 1   04-04                    0.250
# 2   04-05                    0.273
# 3   04-07                    0.267
# 4   04-08                    0.263
# 5   04-11                    0.261
# 6   04-13                    0.231
# 7   04-14                    0.200
# 8   04-15                    0.212
# 9   04-18                    0.189
# 10  04-19                    0.200
# 11  04-20                    0.190
# 12  04-21                    0.188
# 13  04-22                    0.192
# 14  04-24                    0.204
# 15  04-25                    0.193
# 16  04-26                    0.230
# 17  04-28                    0.219
# 18  04-30                    0.206
# 19  05-02                    0.211
# 20  05-04                    0.213
# 21  05-05                    0.228
# 22  05-06                    0.220
# 23  05-07                    0.212
# 24  05-08                    0.200
# 25  05-09                    0.202
# ...

# %%
maybin_2017_2 = pd.read_csv('csv_from_scrape/maybin_2017_2_df.csv')
maybin_2017_2.columns.values[1] = 'DATE'
maybin_2017_2.columns.values[2] = '2017 Batting Averages 2'
maybin_2017_2.drop('Unnamed: 0', axis = 1)
# Out:
#      DATE  2017 Batting Averages 2
# 0   09-02                    0.200
# 1   09-02                    0.200
# 2   09-03                    0.222
# 3   09-04                    0.182
# 4   09-05                    0.214
# 5   09-06                    0.250
# 6   09-08                    0.200
# 7   09-09                    0.160
# 8   09-10                    0.148
# 9   09-13                    0.133
# 10  09-14                    0.133
# 11  09-15                    0.147
# 12  09-20                    0.132
# 13  09-22                    0.128
# 14  09-23                    0.116
# 15  09-24                    0.130
# 16  09-25                    0.130
# 17  09-26                    0.160
# 18  09-28                    0.182
# 19  09-29                    0.182
# 20  09-30                    0.186

# %%
frames = [dates, maybin_2007, maybin_2009, maybin_2010, maybin_2011, maybin_2012, maybin_2013, maybin_2014, 
         maybin_2015, maybin_2016, maybin_2017_1, maybin_2017_2]

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'], how='outer'), frames)

# %%
drops = ['Unnamed: 0_x', 'Unnamed: 0_y', 'Unnamed: 0']

# %%
maybin_batting = df_merged.drop(drops, axis = 1)

# %%
maybin_batting.to_csv('data_aggregated/maybin_batting.csv', index=False)
